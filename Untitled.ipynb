# %%
from skimage.io import imread_collection, imshow
aseman_folder = 'data_batik/Aseman/*.jpg'
aseman = imread_collection(aseman_folder)

bledak_folder = 'data_batik/Aseman/*.jpg'
bledak = imread_collection(bledak_folder)

gunung_ringgit_folder = 'data_batik/GunungRinggit/*.jpg'
gunung_ringgit = imread_collection(gunung_ringgit_folder)

krecak_folder = 'data_batik/Krecak/*.jpg'
krecak = imread_collection(krecak_folder)

latohan_folder = 'data_batik/Latohan/*.jpg'
latohan = imread_collection(latohan_folder)

naga_folder = 'data_batik/Naga/*.jpg'
naga = imread_collection(naga_folder)

sekar_jagat_folder = 'data_batik/SekarJagat/*.jpg'
sekar_jagat = imread_collection(sekar_jagat_folder)

# %%
imshow(sekar_jagat[0])
print(len(sekar_jagat))
# Out:
# 160
